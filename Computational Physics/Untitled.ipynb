# %%
def add_thingy(s, c):
    """
    inputs: 
    s = your value you are checking
    c = a list or array of your values. It would look like c = [c1,c2,c3...c10]
    
    outputs:
    none, the replacement should be inplace
    """
    
    for n in range(0,9): #runs for 1 less than your length, 0-8 (9 times)
        if n <= s < n+1:
            c[n] += 1    #add it to the nth element if it is true, you can convince yourself it will do the right thing
            return       #Breaks once it finds a match 
    
    #If no match is found it adds then breaks
    c[10] += 1
    return

# %%
import numpy as np
E = 4.4e6
U = 50e6
L = 1e-6
hc = 1240
m = 938e6
a = 2*np.pi*np.sqrt(2*m*(U-E))/hc

T = 1/(1+0.25*(U**2/(E*(U-E)))*np.sinh(a*L)**2)

print("T = " + str(T))

T2 = np.exp((-4*np.pi*np.sqrt(2*m)/hc)*(np.sqrt(U-E)*L))

print("T2 = " + str(T2))
# Out:
# T = 0.06862350431157181
# T2 = 0.05160894950023433

# %%
for i in range(1,4):
    for n in range(1,7):
        for m in range(1,10):
            print("{:d}, {:d}, {:d}, total: {:f}".format(i, n, m, i + n/4 + m/9))
# Out:
# 1, 1, 1, total: 1.361111
# 1, 1, 2, total: 1.472222
# 1, 1, 3, total: 1.583333
# 1, 1, 4, total: 1.694444
# 1, 1, 5, total: 1.805556
# 1, 1, 6, total: 1.916667
# 1, 1, 7, total: 2.027778
# 1, 1, 8, total: 2.138889
# 1, 1, 9, total: 2.250000
# 1, 2, 1, total: 1.611111
# 1, 2, 2, total: 1.722222
# 1, 2, 3, total: 1.833333
# 1, 2, 4, total: 1.944444
# 1, 2, 5, total: 2.055556
# 1, 2, 6, total: 2.166667
# 1, 2, 7, total: 2.277778
# 1, 2, 8, total: 2.388889
# 1, 2, 9, total: 2.500000
# 1, 3, 1, total: 1.861111
# 1, 3, 2, total: 1.972222
# 1, 3, 3, total: 2.083333
# 1, 3, 4, total: 2.194444
# 1, 3, 5, total: 2.305556
# 1, 3, 6, total: 2.416667
# 1, 3, 7, total: 2.527778
# 1, 3, 8, total: 2.638889
# 1, 3, 9, total: 2.750000
# 1, 4, 1, total: 2.111111
# 1, 4, 2, total: 2.222222
# 1, 4, 3, total: 2.333333
# 1, 4, 4, total: 2.444444
# 1, 4, 5, total: 2.555556
# 1, 4, 6, total: 2.666667
# 1, 4, 7, total: 2.777778
# 1, 4, 8, total: 2.888889
# 1, 4, 9, total: 3.000000
# 1, 5, 1, total: 2.361111
# ...
